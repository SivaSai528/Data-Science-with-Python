# %%
import pandas as pd

# %%
df=pd.read_csv("2m Sales Records.csv")

# %%
df
# Out:
#                                    Region     Country      Item Type  \
# 0                   Australia and Oceania   Australia           Meat
# 1                                    Asia  Tajikistan  Personal Care
# 2                      Sub-Saharan Africa  Mozambique      Cosmetics
# 3       Central America and the Caribbean      Panama  Personal Care
# 4                           North America      Canada         Fruits
# ...                                   ...         ...            ...
# 873788                               Asia       Japan      Beverages
# 873789                               Asia   Sri Lanka        Clothes
# 873790                 Sub-Saharan Africa       Gabon      Cosmetics
# 873791                               Asia      Bhutan      Baby Food
# 873792                             Europe     Belarus         Snacks
#
#        Sales Channel Order Priority  Order Date     Order ID   Ship Date  \
# ...

# %%
df.head(10)
# Out:
#                               Region                 Country      Item Type  \
# 0              Australia and Oceania               Australia           Meat
# 1                               Asia              Tajikistan  Personal Care
# 2                 Sub-Saharan Africa              Mozambique      Cosmetics
# 3  Central America and the Caribbean                  Panama  Personal Care
# 4                      North America                  Canada         Fruits
# 5                             Europe                   Italy         Fruits
# 6                             Europe                 Romania      Beverages
# 7              Australia and Oceania               Australia      Cosmetics
# 8                             Europe  Bosnia and Herzegovina      Cosmetics
# 9                               Asia                   Japan        Clothes
#
#   Sales Channel Order Priority  Order Date     Order ID   Ship Date  \
# ...
