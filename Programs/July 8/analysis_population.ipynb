# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
a=pd.DataFrame([[100,100,100,100],
               [200,150,110,300],
               [300,200,120,400],
               [400,350,190,300],
               [500,400,210,500],
               [600,450,310,900],
               [700,500,510,500],
               [800,550,610,900],
               [900,650,810,700],
               [1000,1000,1000,1000]])

# %%
a.plot.box()
# Out:
# <AxesSubplot:>

# %%
pop=pd.Series(np.random.rand(100))*1000

# %%
plt.hist(pop)
plt.show()

# %%
print(pop.var())
pop.describe()
# Out:
# 87557.5153102196
# count    100.000000
# mean     477.556871
# std      295.901192
# min       16.487495
# 25%      209.702899
# 50%      488.729936
# 75%      713.174712
# max      999.688325
# dtype: float64

# %%
x=[100,470,298,1,207,461,695,997]
plt.plot(x,marker="o")
plt.show()

# %%
pop1=pd.Series(np.random.rand(100))*500
plt.hist(pop1)
plt.show()

# %%
pop1.describe()
# Out:
# count    100.000000
# mean     228.344293
# std      143.604071
# min        1.707977
# 25%      109.981612
# 50%      215.622652
# 75%      362.582682
# max      481.963741
# dtype: float64

# %%
y=[100,255,146,18,129,254,388,497]
plt.plot(y,marker="o")
plt.show()

# %%
plt.plot(x,marker="o",color="red")
plt.plot(y,marker="o",color="green")
plt.show()

# %%
pop2=pd.Series(np.random.rand(100))*100

# %%
pop2.describe()
# Out:
# count    100.000000
# mean      46.072439
# std       28.845046
# min        0.822233
# 25%       21.749000
# 50%       45.717510
# 75%       70.430669
# max       96.069317
# dtype: float64

# %%
z=[100,50,30,0,19,46,78,99]
plt.plot(x,marker="o",color="red")
plt.plot(y,marker="o",color="green")
plt.plot(z,marker="o")
plt.show()

# %%
plt.subplot(2,2,1)
plt.hist(pop)
plt.subplot(2,2,2)
plt.hist(pop1)
plt.subplot(2,2,3)
plt.hist(pop2)
plt.show()

# %%
a1=pd.Series(np.random.randint(1,1000,1000))
a2=pd.Series(np.random.randint(1,1000,1000))
a3=pd.Series(np.random.randint(1,1000,1000))
print(a1.describe())
print(a2.describe())
print(a3.describe())
print(a1.mode())
print(a2.mode())
print(a3.mode())
# Out:
# count    1000.00000
# mean      514.38800
# std       289.91581
# min         2.00000
# 25%       246.00000
# 50%       524.50000
# 75%       767.25000
# max       998.00000
# dtype: float64
# count    1000.000000
# mean      492.376000
# std       292.380624
# min         1.000000
# 25%       234.750000
# 50%       479.000000
# 75%       748.000000
# max       998.000000
# dtype: float64
# count    1000.000000
# mean      500.603000
# std       283.271633
# min         4.000000
# 25%       259.000000
# 50%       493.000000
# 75%       747.750000
# max       999.000000
# dtype: float64
# 0    729
# dtype: int32
# 0    102
# 1    113
# 2    189
# 3    707
# dtype: int32
# 0     96
# 1    440
# 2    560
# 3    832
# dtype: int32

# %%
x=[1000,489,284,1,234,501,722,999,729]
y=[1000,498,290,1,249,494,750,997,707]
z=[1000,505,287,1,251,519,749,990,832]
plt.plot(x,marker="o",color="red")
plt.plot(y,marker="o",color="green")
plt.plot(z,marker="o")
plt.show()
