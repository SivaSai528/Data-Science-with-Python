# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Line Graph")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
X=[1,2,3,4,5]
Y=[1,2,3,4,5]
plt.plot(X,Y)
plt.show()

# %%
plt.scatter(X,Y)
plt.show()

# %%
plt.plot(X,Y,"--")
plt.show()

# %%
plt.plot(X,Y,"4")
plt.show()

# %%
xp=np.arange(5)
xp
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.plot(X,Y,Marker="o",mec="black",color="pink",linewidth="3")
plt.show()
# Out:
# C:\Users\Siva\AppData\Local\Temp/ipykernel_4560/3154759200.py:1: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(X,Y,Marker="o",mec="black",color="pink",linewidth="3")

# %%
plt.plot(X,Y,Marker="o",mec="black",color="yellow",linewidth="5")
plt.show()
# Out:
# C:\Users\Siva\AppData\Local\Temp/ipykernel_4560/4292391531.py:1: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.plot(X,Y,Marker="o",mec="black",color="yellow",linewidth="5")

# %%
X=[1,1,3,5,5,3.5,3.5,2.5,2.5,1,5,5,4,4,3.5]
Y=[1,3,5,3,1,1,3,3,1,1,1,3,4,4.5,4.5]
plt.plot(X,Y)
plt.show()

# %%
X=[1,1,4,4,1]
Y=[1,4,4,1,1]
plt.plot(X,Y,marker="*",color="r")
plt.plot([1,2.5,4],[4,2.5,4],marker="*",color="black")
plt.show()

# %%
X=[1,1,6,6,1]
Y=[1,6,6,1,1]
A=[1,3.5,6]
B=[6,9,6]
plt.plot(A,B,color="black",marker="o")
plt.plot(X,Y,marker="o",color="r")
plt.plot([2,2],[1,6],color="black",marker="o")
plt.plot([3,3],[1,6],color="yellow",marker="o")
plt.plot([4,4],[1,6],color="blue",marker="o")
plt.plot([5,5],[1,6],color="pink",marker="o")
plt.plot([1.85,5.15],[7,7],color="orange",marker="o")
plt.plot([2.65,4.32],[8,8],color="green",marker="o")
plt.show()
